# %%
import torch
from matplotlib import pyplot as plt 
plt.style.use('seaborn-v0_8-whitegrid')

def regression_data(n = 100, w = torch.Tensor([-0.7, 0.5]), x_max = 1):

    x = torch.rand(n)*x_max
    y = x*w[1] + w[0] + 0.05*torch.randn(n)
    return x, y

x, y = regression_data()

plt.scatter(x, y, facecolors = "none", edgecolors = "steelblue")
labs = plt.gca().set(xlabel = r"$x$", ylabel = r"$y$")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
def stochastic_gradient_descent (max_epoch, x, y, alpha):
    w_0 = 0
    w_1 = 0
    alpha = 0.5
    for epoch in range(1, max_epoch + 1):
        epoch_rand_order = torch.random.permutation(len (x))
        #i = torch.randint(0, x.shape[0], (batch_size,))


        for i in epoch_rand_order:
            w_0 = w_0 - (2*alpha / epoch) * w_0 * (y[i] - w_1*x[i] -w_0)
            w_1 = w_1 - (2*alpha / epoch) * w_1 * (y[1] - w_1*x[i] -w_0) * x[i]

    return w_0, w_1

# %% [markdown]
# James:
# - Almost have some of the results and everything --> challenge is "what is the scope?" Trying to predict stocks with data over time and have the results for some stocks in energy sectors and have basic info of the last 30 and 50 days --> found they can get better tha 50% accuraacy and good consisitent positive reult --> have charts eith strategy and market returns
#
# Julia and SOphie:
# - did model on all diff kinds of medical problems like pregnancies, hearth related issues, diabeties, etc, --> trained model to all of these problems and made predictions on diferent idenity factors like race and saw if there were patters--> found that poeple who live in richer towns in Massachussetts. have lower risks of diabities --> sign model is working and men are more likely to get diabities which is correct with google search --> weird result with lung issues where everyone gers 50% of getting lung disease
#
# oscar and tristan:
# - 70,000 accounts of fraud --> to get around that they did neural network with Logistic Regression and cosntructed data loader usign proportional random sampling --> a lot of math, got it and crated a Logistic Regression model that is very accurate --> classifies fraud to about 80% and not fraud to about 95% --> created decision tree model which was able to use other categorical features and when on trianing data, had a good classification rate bc a lot of fraud comes form a small subset of merchants in the credit card transactions --> able to analyze relative features importance like amounts at the top with large amounts of transactions being at the top, specific merchants have higher rate of fraud bc they are the fraudsters
